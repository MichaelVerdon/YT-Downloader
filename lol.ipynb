# %%
list = "helloworld=2384728934"

# %%
list.split("=")[1]
# Out:
# '2384728934'

# %%
import requests
request = requests.get("https://img.youtube.com/vi/8aWgSD8Sq0A/maxresdefault.jpg")
request
from PIL import ImageTk, Image

# %%
from IPython.display import Image, display

# %%
from io import BytesIO
display(Image((request.content)))
